# %% [markdown]
# # 1 - Import Library

# %%
# Load Model
from tensorflow.keras.models import load_model
import pickle
import json
import pandas as pd
import numpy as np

# %% [markdown]
# # 2 - Load Model

# %%
with open('final_pipeline.pkl', 'rb') as file_1:
  model_pipeline = pickle.load(file_1)

with open("list_num_cols.txt", "r") as file_2:
    list_num_cols = json.load(file_2)

with open("list_catn_cols.txt", "r") as file_3:
    list_catn_cols = json.load(file_3)

model_ann = load_model('churn_predict_model.h5')

# %% [markdown]
# # 3 - Data Loading

# %%
data_inf = {'user_id': {0: 'a4g48a3ea45d4a6d',
  1: 'uaaofoaserabjfah',
  2: 'f54atga4rg6a4w67',
  3: 'g4ea46ae8a8f7a5d',
  4: 'jsiugrg46aaf1fea'},
 'age': {0: 40, 1: 36, 2: 17, 3: 74, 4: 50},
 'gender': {0: 'M', 1: 'M', 2: 'M', 3: 'F', 4: 'F'},
 'region_category': {0: 'Town', 1: 'City', 2: 'Village', 3: 'City', 4: 'Town'},
 'membership_category': {0: 'Premium Membership',
  1: 'Basic Membership',
  2: 'Silver Membership',
  3: 'No Membership',
  4: 'Platinum Membership'},
 'joining_date': {0: '2018-12-15 00:00:00',
  1: '2015-01-16 00:00:00',
  2: '2016-03-28 00:00:00',
  3: '2017-10-01 00:00:00',
  4: '2015-09-07 00:00:00'},
 'joined_through_referral': {0: 'Yes', 1: 'No', 2: 'Yes', 3: 'No', 4: 'No'},
 'preferred_offer_types': {0: 'Credit/Debit Card Offers',
  1: 'Without Offers',
  2: 'Gift Vouchers/Coupons',
  3: 'Credit/Debit Card Offers',
  4: 'Gift Vouchers/Coupons'},
 'medium_of_operation': {0: 'Smartphone',
  1: 'Desktop',
  2: 'Desktop',
  3: 'Desktop',
  4: 'Smartphone'},
 'internet_option': {0: 'Wi-Fi',
  1: 'Fiber_Optic',
  2: 'Wi-Fi',
  3: 'Wi-Fi',
  4: 'Fiber_Optic'},
 'last_visit_time': {0: '22:29:49',
  1: '15:44:56',
  2: '20:31:53',
  3: '14:28:05',
  4: '04:16:48'},
 'days_since_last_login': {0: 6, 1: 15, 2: 25, 3: 1, 4: 35},
 'avg_time_spent': {0: 1241.49, 1: 420.15, 2: 113.14, 3: 76.67, 4: 162.99},
 'avg_transaction_value': {0: 40321.69,
  1: 6891.66,
  2: 35614.69,
  3: 14657.14,
  4: 7943.68},
 'avg_frequency_login_days': {0: 13.0, 1: 17.0, 2: 14.0, 3: 3.0, 4: 0.0},
 'points_in_wallet': {0: 675.48, 1: 611.97, 2: 821.93, 3: 497.22, 4: 1032.04},
 'used_special_discount': {0: 'No', 1: 'No', 2: 'Yes', 3: 'No', 4: 'Yes'},
 'offer_application_preference': {0: 'Yes',
  1: 'No',
  2: 'Yes',
  3: 'No',
  4: 'No'},
 'past_complaint': {0: 'Yes', 1: 'No', 2: 'No', 3: 'Yes', 4: 'Yes'},
 'complaint_status': {0: 'Not Applicable',
  1: 'No Information Available',
  2: 'Not Applicable',
  3: 'No Information Available',
  4: 'Not Applicable'},
 'feedback': {0: 'Products always in Stock',
  1: 'Poor Customer Service',
  2: 'Too many ads',
  3: 'Quality Customer Care',
  4: 'Poor Product Quality'}}

# %%
data_inf = pd.DataFrame(data_inf)
data_inf
# Out:
#             user_id  age gender region_category  membership_category  \
# 0  a4g48a3ea45d4a6d   40      M            Town   Premium Membership
# 1  uaaofoaserabjfah   36      M            City     Basic Membership
# 2  f54atga4rg6a4w67   17      M         Village    Silver Membership
# 3  g4ea46ae8a8f7a5d   74      F            City        No Membership
# 4  jsiugrg46aaf1fea   50      F            Town  Platinum Membership
#
#           joining_date joined_through_referral     preferred_offer_types  \
# 0  2018-12-15 00:00:00                     Yes  Credit/Debit Card Offers
# 1  2015-01-16 00:00:00                      No            Without Offers
# 2  2016-03-28 00:00:00                     Yes     Gift Vouchers/Coupons
# 3  2017-10-01 00:00:00                      No  Credit/Debit Card Offers
# 4  2015-09-07 00:00:00                      No     Gift Vouchers/Coupons
#
#   medium_of_operation internet_option  ... days_since_last_login  \
# ...

# %% [markdown]
# # 4 - Inferencing

# %%
num_cols = list_num_cols
catn_cols = list_catn_cols

# %%
data_inf_transform = model_pipeline.transform(data_inf)

# %%
y_pred_inf = model_ann.predict(data_inf_transform)
y_pred_inf = np.where(y_pred_inf>=0.5,1,0)
y_pred_inf
# Out:
# 1/1 [==============================] - 0s 75ms/step
# array([[0],
#        [1],
#        [0],
#        [0],
#        [0]])

# %%
data_inf["churn_risk_score"] = y_pred_inf

# %%
data_inf
# Out:
#             user_id  age gender region_category  membership_category  \
# 0  a4g48a3ea45d4a6d   40      M            Town   Premium Membership
# 1  uaaofoaserabjfah   36      M            City     Basic Membership
# 2  f54atga4rg6a4w67   17      M         Village    Silver Membership
# 3  g4ea46ae8a8f7a5d   74      F            City        No Membership
# 4  jsiugrg46aaf1fea   50      F            Town  Platinum Membership
#
#           joining_date joined_through_referral     preferred_offer_types  \
# 0  2018-12-15 00:00:00                     Yes  Credit/Debit Card Offers
# 1  2015-01-16 00:00:00                      No            Without Offers
# 2  2016-03-28 00:00:00                     Yes     Gift Vouchers/Coupons
# 3  2017-10-01 00:00:00                      No  Credit/Debit Card Offers
# 4  2015-09-07 00:00:00                      No     Gift Vouchers/Coupons
#
#   medium_of_operation internet_option  ... avg_time_spent  \
# ...
